# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import pandas as pd
import numpy as np
import pyreadr
import config_91
import utils_91
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
fold = '1.0'
clf_cfg = config_91.classifier_config
HISTORY_DIR = clf_cfg['NN91_HISTORY_DIR']
with open(os.path.join(HISTORY_DIR, f'{fold}.pkl'), 'rb') as handle:
    fold_history = pickle.load(handle)

print(fold_history)
# Out:
# {'train_accs': [54.99092558983666, 84.39201451905626, 93.28493647912886, 95.78039927404718, 96.64246823956442, 97.36842105263158, 98.59346642468239, 99.09255898366605, 99.04718693284936, 98.91107078039929, 98.91107078039929, 99.54627949183303, 99.72776769509983, 99.8638838475499, 99.68239564428312, 99.9546279491833, 99.9546279491833, 99.90925589836661, 99.72776769509983, 99.9546279491833, 99.8638838475499, 99.9546279491833, 99.90925589836661, 100.0, 99.72776769509983, 99.90925589836661, 99.68239564428312, 99.90925589836661, 100.0, 100.0], 'train_losses': [2.218462233202181, 0.6967272646995126, 0.3788878755724948, 0.24949984713052603, 0.19534942942698472, 0.1500042425552923, 0.11361898959317393, 0.09066632524321692, 0.07577599252175972, 0.06936462897051504, 0.06141297840277084, 0.0504147556502426, 0.04041481366890577, 0.036175588949792684, 0.03240000019254892, 0.027585764811627323, 0.024141083129401573, 0.021266875967832173, 0.025258235543109207, 0.01784224678893857, 0.020083959998294
# ...

# %%
plt.figure(figsize=(10, 5))
plt.plot(fold_history['train_accs'])
plt.plot(fold_history['val_accs'])
plt.title(f'Fold {fold} accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc = 'best')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(fold_history['train_losses'])
plt.plot(fold_history['val_losses'])
plt.title(f'Fold {fold} loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc = 'best')
plt.show()
