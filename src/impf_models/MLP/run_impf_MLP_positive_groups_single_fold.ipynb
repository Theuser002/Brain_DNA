# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
import sys
sys.path.append('../../../src/')
import warnings
warnings.filterwarnings("ignore")

import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import config
import itertools
import utils
import pickle

from utils import impf_make_ndarray_from_csv, get_int_label, brier_score_tensor
from Dataset import CNS
from torch.utils.data import DataLoader
from torch.nn import CrossEntropyLoss
from torch.optim import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score 
from torch.nn.functional import softmax, one_hot
from sklearn.metrics import confusion_matrix
from imblearn.over_sampling import SMOTE, RandomOverSampler
from sklearn.utils.class_weight import compute_class_weight

# %%
class Impf_DNAMLP(nn.Module):
    def __init__ (self, in_features, n_classes):
        super(Impf_DNAMLP, self).__init__()
        self.in_features = in_features
        
        self.n_classes = n_classes
        self.densenet = nn.Sequential(
            nn.Linear(self.in_features, self.n_classes),
        )
        
    def forward (self, x):
        x = self.densenet(x)
        return x

# %%
def impf_train_epoch(epoch, model, train_loader, criterion, optimizer, device):
    correct = 0
    total = 0
    total_loss = 0
    total_bs = 0
    model.to(device)
    model.train()
    
    # For loop through all batches
    all_labels = []
    all_logits = []
    for features, labels in train_loader:
        # Move tensors to device
        features = features.to(device)
        labels = labels.to(device)
        
        # Zero out gradient
        optimizer.zero_grad()
        
        # Forward pass
        logits = model(features)
        loss = criterion(logits, labels)

        # Backward pass
        loss.backward()
        optimizer.step()
        
        # Evaluation
        total_loss += loss.item()
        _, predicted = logits.max(1)
        correct += predicted.eq(labels).sum().item()
        total += labels.size(0)
        
        # batch BS
        batch_bs = brier_score_tensor(logits, labels)
        total_bs += batch_bs
        
        # save logits and labels to calculate AUC
        for logit, label in zip(logits, labels):
            all_labels.append(label.item())
            all_logits.append(np.array(logit.detach().cpu().numpy()))
        
    # epoch's avrage LL
    train_loss = total_loss / len(train_loader)
    # epoch's average acc & ME
    train_acc = (correct / total) * 100.
    train_me = 100 - train_acc
    # epoch's average BS
    train_bs = total_bs/len(train_loader)
    # epoch's average AUC
    # all_labels_one_hot = one_hot(torch.Tensor(np.array(all_labels)).long())
    all_probs = softmax(torch.Tensor(np.array(all_logits)), dim = 1)
    # train_auc = roc_auc_score(all_labels_one_hot, all_probs)
    
    all_preds = [np.argmax(prob) for prob in all_probs]
    train_auc = roc_auc_score(all_labels, all_preds)
    train_precision = precision_score(all_labels, all_preds)
    train_recall = recall_score(all_labels, all_preds)
    train_cfs = confusion_matrix(all_labels, all_preds)
    
    return train_loss, train_acc, train_me, train_bs, train_auc, train_precision, train_recall, train_cfs

def impf_val_epoch(epoch, model, val_loader, criterion, device):
    correct = 0
    total = 0
    total_loss = 0
    total_bs = 0
    model.to(device)
    # For loop through all batches
    with torch.no_grad():
        # For loop through all batches
        all_labels = []
        all_logits = []
        for features, labels in val_loader:
            # Move tensors to device
            features, labels = features.to(device), labels.to(device)
            # Forward pass
            logits = model(features)
            
            # Evaluation and batch loss
            loss = criterion(logits, labels)
            total_loss += loss.item()
            _, predicted = logits.max(1)
            correct += predicted.eq(labels).sum().item()
            total  += labels.size(0)
            
            # batch BS
            batch_bs = brier_score_tensor(logits, labels)
            total_bs += batch_bs
            
            # save logits and labels to calculate AUC
            for logit, label in zip(logits,labels):
                all_labels.append(label.item())
                all_logits.append(np.array(logit.detach().cpu().numpy()))
        
        # epoch's average LL
        val_loss = total_loss / len(val_loader)
        # epoch's average acc & ME
        val_acc = (correct / total) * 100
        val_me = (100 - val_acc)
        # epoch's average BS
        val_bs = total_bs/len(val_loader)
        # epoch's AUC
        # all_labels_one_hot = one_hot(torch.Tensor(np.array(all_labels)).long())
        all_probs = softmax(torch.Tensor(np.array(all_logits)), dim = 1)
        # val_auc = roc_auc_score(all_labels_one_hot, all_probs)
        
        all_preds = [np.argmax(prob) for prob in all_probs]
        val_auc = roc_auc_score(all_labels, all_preds)
        val_precision = precision_score(all_labels, all_preds)
        val_recall = recall_score(all_labels, all_preds)
        val_cfs = confusion_matrix(all_labels, all_preds)
         
    return val_loss, val_acc, val_me, val_bs, val_auc, val_precision, val_recall, val_cfs

def impf_run(class_name, alg, fold, train_loader, val_loader, model, criterion, optimizer, config, save):
    history = {'val_accs': [], 'val_losses': [], 'val_precisions': [], 'val_recalls': [], 'val_aucs': [], 'test_accs': [], 'test_losses': [], 'test_precisions': [], 'test_recalls': [], 'test_aucs': []}
    
    model.to(config['device'])
    n_epochs = config['mlp_n_epochs']
    BEST_STATES_DIR= config['MLP_BEST_STATES_DIR']
    BEST_STATE_PATH = os.path.join(BEST_STATES_DIR, alg, class_name, f'{fold}.pth')
    diff_threshold = config['mlp_diff_threshold']
    max_patience = config['mlp_max_patience']
    patience = 0
    
    for epoch in range(1, n_epochs + 1):
        # print(f'Epoch {epoch}/{n_epochs} of fold {fold} of group {class_name}')
        
        train_loss, train_acc, train_me, train_bs, train_auc, train_precision, train_recall, train_cfs = impf_train_epoch(epoch, model, train_loader, criterion, optimizer, config['device'])
        val_loss, val_acc, val_me, val_bs, val_auc, val_precision, val_recall, val_cfs = impf_val_epoch(epoch, model, val_loader, criterion, config['device'])
        
        # history['val_accs'].append(val_acc)
        history['val_losses'].append(val_loss)
        # history['val_precisions'].append(val_precision)
        # history['val_recalls'].append(val_recall)
        # history['val_aucs'].append(val_auc)
        
        # print(f'[{class_name.upper()}] - {fold} - {epoch}/{n_epochs}')
        # print('train_loss: %.5f | train_acc: %.3f | train_precision: %.3f | train_recall: %.3f | train_auc: %.3f' % (train_loss, train_acc, train_precision, train_bs, train_auc))
        # print('val_loss: %.5f | val_acc: %.3f | val_precision: %.3f | val_recall: %.3f | val_auc: %.3f' % (val_loss, val_acc, val_precision, val_recall, val_auc))
        
        if val_loss == min(history['val_losses']):
            # get best epoch's resutls
            best_epoch_results = {'train_loss: ': train_loss, 'train_accs': train_acc, 'train_me': train_me, 'train_bs': train_bs, 'train_precision': train_precision, 'train_recall': train_recall, 'train_auc': train_auc, 'train_cfs': train_cfs, 'val_loss: ': val_loss, 'val_accs': val_acc, 'val_me': val_me, 'val_bs': val_bs, 'val_precision': val_precision, 'val_recall': val_recall, 'val_auc': val_auc, 'val_cfs': val_cfs}
            if save.lower() == 'save':
                print('Lowest validation loss => saving model weights...')
                torch.save(model.state_dict(), BEST_STATE_PATH)
        if len(history['val_losses']) > 1:
            patience = patience + 1
            # print(f'Patience increased to {patience}')
            if patience == max_patience:
                # print('Early stopping.')
                break
            else:
                patience = 0
        # print('---------------------------------------------')
    return best_epoch_results

# %%
clf_cfg = config.classifier_config
impf_cfg = config.impf_config
groups = utils.positive_groups
folds = utils.outer_folds
fold = folds[np.random.randint(len(folds))]
algs = utils.algs
outer_fold = f'{fold.split(".")[0]}.0'
device = impf_cfg['device']

fold = '1.1'
outer_fold = '1.0'
alg = "MLP"
save = 'no_save'
use_SMOTE_values = [True, False]
use_weights_values = [True, False]
selected_metrics = ['train_precision', 'train_recall', 'train_auc', 'train_cfs', 'val_precision', 'val_recall', 'val_auc', 'val_cfs']

# %%
print(f'root: {config.root_dir}')
print(f"device: {device}")
print(f'save mode: {save}')
print(f'fold: {fold}')
print(f'alg: {alg}')
for group in groups:
    print (f'\n\n========{group.upper()}========')
    # Load impf
    with open(os.path.join(impf_cfg['IMPORTANT_FEATURES_DIR'], alg, group, f'{outer_fold}_combined.pkl'), 'rb') as file:
        impf = pickle.load(file)    
    # Read from csv to dataframe
    features, labels = impf_make_ndarray_from_csv(group, fold, impf, mode = 'all')
    # Train test split
    train_features, val_features, train_labels, val_labels = train_test_split(features, labels, test_size=0.8, random_state=42)
    value_counts = pd.Series(train_labels).value_counts()
    print(f'{value_counts}')
    for use_SMOTE in use_SMOTE_values:
        for use_weights in use_weights_values:
            if use_weights == True:
                class_weights = torch.Tensor(compute_class_weight(class_weight='balanced', classes=np.unique(train_labels), y = train_labels )).to(device)
            else:
                class_weights = None
            if use_SMOTE == True:
                smote = SMOTE(sampling_strategy = "auto", random_state = 42, k_neighbors = max(1, min(value_counts) - 1)))
                new_train_features, new_train_labels = smote.fit_resample(train_features, train_labels)
            else:
                new_train_features, new_train_labels = train_features, train_labels
                
            # Encode the labels
            new_train_labels_int = np.array([get_int_label(label, group) for label in new_train_labels])
            val_labels_int = np.array([get_int_label(label, group) for label in val_labels])

            # Create datasets and Dataloaders
            train_dataset = CNS(new_train_features, new_train_labels_int, mode = 'train')
            val_dataset = CNS(val_features, val_labels_int, mode = 'val')
            train_loader = DataLoader(train_dataset, batch_size = impf_cfg['mlp_train_batch_size'], shuffle = True)
            val_loader = DataLoader(val_dataset, batch_size = impf_cfg['mlp_val_batch_size'], shuffle = False)

            # Init model object
            in_features = len(impf)
            model = Impf_DNAMLP(in_features, impf_cfg['n_classes'])
                
            # Define hyperparams
            criterion = CrossEntropyLoss(weight=class_weights)
            optimizer = Adam(model.parameters(), lr = impf_cfg['mlp_lr'], weight_decay = impf_cfg['mlp_weight_decay'])

            best_epoch_results = impf_run(group, alg, fold, train_loader, val_loader, model, criterion, optimizer, impf_cfg, save) 
            print(f'--------\n-> SMOTE: {use_SMOTE} - WEIGHTS: {use_weights} | Best epoch: ')
            for key, value in best_epoch_results.items():
                if key in selected_metrics:
                    if 'cfs' in key:
                        print(f'\t{key}:\n{value}')
                    else:
                        print(f'\t{key}: {value}')
# Out:
# root: D:\#Study\Thesis\Code\Brain_DNA\src\..
# device: cpu
# save mode: no_save
# fold: 1.1
# alg: MLP
#
#
# ========EMBRYONAL========
# Embryonal    96
# Control      18
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 0.19791666666666666
# 	train_auc: 0.5989583333333334
# 	train_cfs:
# [[96  0]
#  [77 19]]
# 	val_precision: 1.0
# 	val_recall: 0.12162162162162163
# 	val_auc: 0.5608108108108109
# 	val_cfs:
# [[385   0]
#  [ 65   9]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.979381443298969
# 	train_recall: 0.9895833333333334
# 	train_auc: 0.984375
# 	train_cfs:
# [[94  2]
#  [ 1 95]]
# 	val_precision: 0.948051948051948
# 	val_recall: 0.9864864864864865
# 	val_auc: 0.988048438048438
# 	val_cfs:
# [[381   4]
#  [  1  73]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.34210526315789475
# 	train_recall: 0.7222222222222222
# 	train_auc: 0.7309027777777778
# 	train_cfs:
# [[71 25]
#  [ 5 13]]
# 	val_precision: 0.36885245901639346
# 	val_recall: 0.6081081081081081
# 	val_auc: 0.7040540540540542
# 	val_cfs:
# [[308  77]
#  [ 29  45]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 0.0
# 	train_recall: 0.0
# 	train_auc: 0.5
# 	train_cfs:
# [[96  0]
#  [18  0]]
# 	val_precision: 0.0
# 	val_recall: 0.0
# 	val_auc: 0.5
# 	val_cfs:
# [[385   0]
#  [ 74   0]]
#
#
# ========GLIOBLASTOMA========
# Glioblastoma    66
# Control         19
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 0.0
# 	train_recall: 0.0
# 	train_auc: 0.5
# 	train_cfs:
# [[66  0]
#  [66  0]]
# 	val_precision: 0.0
# 	val_recall: 0.0
# 	val_auc: 0.5
# 	val_cfs:
# [[270   0]
#  [ 73   0]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.5454545454545454
# 	train_recall: 1.0
# 	train_auc: 0.5833333333333333
# 	train_cfs:
# [[11 55]
#  [ 0 66]]
# 	val_precision: 0.2425249169435216
# 	val_recall: 1.0
# 	val_auc: 0.5777777777777777
# 	val_cfs:
# [[ 42 228]
#  [  0  73]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.0
# 	train_recall: 0.0
# 	train_auc: 0.5
# 	train_cfs:
# [[66  0]
#  [19  0]]
# 	val_precision: 0.0
# 	val_recall: 0.0
# 	val_auc: 0.4981481481481482
# 	val_cfs:
# [[269   1]
#  [ 73   0]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 0.0
# 	train_recall: 0.0
# 	train_auc: 0.5
# 	train_cfs:
# [[66  0]
#  [19  0]]
# 	val_precision: 0.0
# 	val_recall: 0.0
# 	val_auc: 0.5
# 	val_cfs:
# [[270   0]
#  [ 73   0]]
#
#
# ========GLIO-NEURONAL========
# Glio-neuronal    29
# Control          20
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 0.9444444444444444
# 	train_recall: 0.5862068965517241
# 	train_auc: 0.7758620689655173
# 	train_cfs:
# [[28  1]
#  [12 17]]
# 	val_precision: 0.8775510204081632
# 	val_recall: 0.5972222222222222
# 	val_auc: 0.7746111111111111
# 	val_cfs:
# [[119   6]
#  [ 29  43]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.6829268292682927
# 	train_recall: 0.9655172413793104
# 	train_auc: 0.7586206896551724
# 	train_cfs:
# [[16 13]
#  [ 1 28]]
# 	val_precision: 0.5217391304347826
# 	val_recall: 1.0
# 	val_auc: 0.736
# 	val_cfs:
# [[59 66]
#  [ 0 72]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.0
# 	train_recall: 0.0
# 	train_auc: 0.5
# 	train_cfs:
# [[29  0]
#  [20  0]]
# 	val_precision: 0.0
# 	val_recall: 0.0
# 	val_auc: 0.5
# 	val_cfs:
# [[125   0]
#  [ 72   0]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 0.6
# 	train_recall: 0.6
# 	train_auc: 0.6620689655172414
# 	train_cfs:
# [[21  8]
#  [ 8 12]]
# 	val_precision: 0.7586206896551724
# 	val_recall: 0.6111111111111112
# 	val_auc: 0.7495555555555556
# 	val_cfs:
# [[111  14]
#  [ 28  44]]
#
#
# ========SELLA========
# Sella      26
# Control    18
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 0.7027027027027027
# 	train_recall: 1.0
# 	train_auc: 0.7884615384615384
# 	train_cfs:
# [[15 11]
#  [ 0 26]]
# 	val_precision: 0.7078651685393258
# 	val_recall: 0.8513513513513513
# 	val_auc: 0.8030341662417135
# 	val_cfs:
# [[80 26]
#  [11 63]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.5
# 	train_recall: 1.0
# 	train_auc: 0.5
# 	train_cfs:
# [[ 0 26]
#  [ 0 26]]
# 	val_precision: 0.4111111111111111
# 	val_recall: 1.0
# 	val_auc: 0.5
# 	val_cfs:
# [[  0 106]
#  [  0  74]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 0.1111111111111111
# 	train_auc: 0.5555555555555556
# 	train_cfs:
# [[26  0]
#  [16  2]]
# 	val_precision: 1.0
# 	val_recall: 0.04054054054054054
# 	val_auc: 0.5202702702702703
# 	val_cfs:
# [[106   0]
#  [ 71   3]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 0.48
# 	train_recall: 0.6666666666666666
# 	train_auc: 0.5833333333333333
# 	train_cfs:
# [[13 13]
#  [ 6 12]]
# 	val_precision: 0.4661016949152542
# 	val_recall: 0.7432432432432432
# 	val_auc: 0.5744518103008669
# 	val_cfs:
# [[43 63]
#  [19 55]]
#
#
# ========EPENDYMAL========
# Ependymal    50
# Control      22
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 0.8
# 	train_auc: 0.9
# 	train_cfs:
# [[50  0]
#  [10 40]]
# 	val_precision: 1.0
# 	val_recall: 0.7714285714285715
# 	val_auc: 0.8857142857142857
# 	val_cfs:
# [[220   0]
#  [ 16  54]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.7575757575757576
# 	train_recall: 1.0
# 	train_auc: 0.84
# 	train_cfs:
# [[34 16]
#  [ 0 50]]
# 	val_precision: 0.5932203389830508
# 	val_recall: 1.0
# 	val_auc: 0.890909090909091
# 	val_cfs:
# [[172  48]
#  [  0  70]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.0
# 	train_recall: 0.0
# 	train_auc: 0.5
# 	train_cfs:
# [[50  0]
#  [22  0]]
# 	val_precision: 0.0
# 	val_recall: 0.0
# 	val_auc: 0.5
# 	val_cfs:
# [[220   0]
#  [ 70   0]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 0.9090909090909091
# 	train_recall: 0.45454545454545453
# 	train_auc: 0.7172727272727273
# 	train_cfs:
# [[49  1]
#  [12 10]]
# 	val_precision: 0.8157894736842105
# 	val_recall: 0.44285714285714284
# 	val_auc: 0.7055194805194805
# 	val_cfs:
# [[213   7]
#  [ 39  31]]
#
#
# ========OTHER GLIOMA========
# Other glioma    47
# Control         22
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 0.6382978723404256
# 	train_auc: 0.8191489361702128
# 	train_cfs:
# [[47  0]
#  [17 30]]
# 	val_precision: 0.92
# 	val_recall: 0.6571428571428571
# 	val_auc: 0.819047619047619
# 	val_cfs:
# [[206   4]
#  [ 24  46]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.9387755102040817
# 	train_recall: 0.9787234042553191
# 	train_auc: 0.9574468085106382
# 	train_cfs:
# [[44  3]
#  [ 1 46]]
# 	val_precision: 0.7582417582417582
# 	val_recall: 0.9857142857142858
# 	val_auc: 0.9404761904761905
# 	val_cfs:
# [[188  22]
#  [  1  69]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.0
# 	train_recall: 0.0
# 	train_auc: 0.5
# 	train_cfs:
# [[47  0]
#  [22  0]]
# 	val_precision: 0.0
# 	val_recall: 0.0
# 	val_auc: 0.5
# 	val_cfs:
# [[210   0]
#  [ 70   0]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 0.13636363636363635
# 	train_auc: 0.5681818181818181
# 	train_cfs:
# [[47  0]
#  [19  3]]
# 	val_precision: 1.0
# 	val_recall: 0.24285714285714285
# 	val_auc: 0.6214285714285714
# 	val_cfs:
# [[210   0]
#  [ 53  17]]
#
#
# ========NERVE========
# Control    19
# Nerve       4
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 0.6129032258064516
# 	train_recall: 1.0
# 	train_auc: 0.6842105263157895
# 	train_cfs:
# [[ 7 12]
#  [ 0 19]]
# 	val_precision: 0.8021978021978022
# 	val_recall: 1.0
# 	val_auc: 0.55
# 	val_cfs:
# [[ 2 18]
#  [ 0 73]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.0
# 	train_recall: 0.0
# 	train_auc: 0.5
# 	train_cfs:
# [[19  0]
#  [19  0]]
# 	val_precision: 0.0
# 	val_recall: 0.0
# 	val_auc: 0.475
# 	val_cfs:
# [[19  1]
#  [73  0]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.8260869565217391
# 	train_recall: 1.0
# 	train_auc: 0.5
# 	train_cfs:
# [[ 0  4]
#  [ 0 19]]
# 	val_precision: 0.7802197802197802
# 	val_recall: 0.9726027397260274
# 	val_auc: 0.4863013698630137
# 	val_cfs:
# [[ 0 20]
#  [ 2 71]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 0.8260869565217391
# 	train_recall: 1.0
# 	train_auc: 0.5
# 	train_cfs:
# [[ 0  4]
#  [ 0 19]]
# 	val_precision: 0.7849462365591398
# 	val_recall: 1.0
# 	val_auc: 0.5
# 	val_cfs:
# [[ 0 20]
#  [ 0 73]]
#
#
# ========PINEAL========
# Pineal     15
# Control    15
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 0.7
# 	train_recall: 0.4666666666666667
# 	train_auc: 0.6333333333333334
# 	train_cfs:
# [[12  3]
#  [ 8  7]]
# 	val_precision: 0.7567567567567568
# 	val_recall: 0.36363636363636365
# 	val_auc: 0.5860735009671181
# 	val_cfs:
# [[38  9]
#  [49 28]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.5
# 	train_recall: 1.0
# 	train_auc: 0.5
# 	train_cfs:
# [[ 0 15]
#  [ 0 15]]
# 	val_precision: 0.6311475409836066
# 	val_recall: 1.0
# 	val_auc: 0.5212765957446808
# 	val_cfs:
# [[ 2 45]
#  [ 0 77]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.5769230769230769
# 	train_recall: 1.0
# 	train_auc: 0.6333333333333333
# 	train_cfs:
# [[ 4 11]
#  [ 0 15]]
# 	val_precision: 0.6666666666666666
# 	val_recall: 0.987012987012987
# 	val_auc: 0.5892511743575574
# 	val_cfs:
# [[ 9 38]
#  [ 1 76]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 0.0
# 	train_recall: 0.0
# 	train_auc: 0.5
# 	train_cfs:
# [[15  0]
#  [15  0]]
# 	val_precision: 0.0
# 	val_recall: 0.0
# 	val_auc: 0.5
# 	val_cfs:
# [[47  0]
#  [77  0]]
#
#
# ========MESENCHYMAL========
# Mesenchymal    25
# Control        19
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 0.7142857142857143
# 	train_recall: 1.0
# 	train_auc: 0.8
# 	train_cfs:
# [[15 10]
#  [ 0 25]]
# 	val_precision: 0.7373737373737373
# 	val_recall: 1.0
# 	val_auc: 0.8785046728971962
# 	val_cfs:
# [[81 26]
#  [ 0 73]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.92
# 	train_recall: 0.92
# 	train_auc: 0.9199999999999999
# 	train_cfs:
# [[23  2]
#  [ 2 23]]
# 	val_precision: 0.8125
# 	val_recall: 0.8904109589041096
# 	val_auc: 0.8751120215081296
# 	val_cfs:
# [[92 15]
#  [ 8 65]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.44
# 	train_recall: 0.5789473684210527
# 	train_auc: 0.5094736842105263
# 	train_cfs:
# [[11 14]
#  [ 8 11]]
# 	val_precision: 0.43209876543209874
# 	val_recall: 0.4794520547945205
# 	val_auc: 0.5247727563692228
# 	val_cfs:
# [[61 46]
#  [38 35]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 0.15789473684210525
# 	train_auc: 0.5789473684210527
# 	train_cfs:
# [[25  0]
#  [16  3]]
# 	val_precision: 1.0
# 	val_recall: 0.273972602739726
# 	val_auc: 0.636986301369863
# 	val_cfs:
# [[107   0]
#  [ 53  20]]
#
#
# ========MELANOCYTIC========
# Control        18
# Melanocytic     4
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 0.2222222222222222
# 	train_auc: 0.6111111111111112
# 	train_cfs:
# [[18  0]
#  [14  4]]
# 	val_precision: 1.0
# 	val_recall: 0.20270270270270271
# 	val_auc: 0.6013513513513513
# 	val_cfs:
# [[17  0]
#  [59 15]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.5
# 	train_recall: 1.0
# 	train_auc: 0.5
# 	train_cfs:
# [[ 0 18]
#  [ 0 18]]
# 	val_precision: 0.8131868131868132
# 	val_recall: 1.0
# 	val_auc: 0.5
# 	val_cfs:
# [[ 0 17]
#  [ 0 74]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.8181818181818182
# 	train_recall: 1.0
# 	train_auc: 0.5
# 	train_cfs:
# [[ 0  4]
#  [ 0 18]]
# 	val_precision: 0.7901234567901234
# 	val_recall: 0.8648648648648649
# 	val_auc: 0.43243243243243246
# 	val_cfs:
# [[ 0 17]
#  [10 64]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 0.8
# 	train_recall: 0.6666666666666666
# 	train_auc: 0.4583333333333333
# 	train_cfs:
# [[ 1  3]
#  [ 6 12]]
# 	val_precision: 0.8166666666666667
# 	val_recall: 0.6621621621621622
# 	val_auc: 0.5075516693163752
# 	val_cfs:
# [[ 6 11]
#  [25 49]]
#
#
# ========PLEXUS========
# Control    19
# Plexus     12
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 0.5454545454545454
# 	train_recall: 0.3157894736842105
# 	train_auc: 0.5263157894736843
# 	train_cfs:
# [[14  5]
#  [13  6]]
# 	val_precision: 0.5277777777777778
# 	val_recall: 0.2602739726027397
# 	val_auc: 0.4697596278108039
# 	val_cfs:
# [[36 17]
#  [54 19]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.23809523809523808
# 	train_recall: 0.2631578947368421
# 	train_auc: 0.21052631578947367
# 	train_cfs:
# [[ 3 16]
#  [14  5]]
# 	val_precision: 0.18032786885245902
# 	val_recall: 0.1506849315068493
# 	val_auc: 0.10364435254587748
# 	val_cfs:
# [[ 3 50]
#  [62 11]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.6206896551724138
# 	train_recall: 0.9473684210526315
# 	train_auc: 0.5153508771929824
# 	train_cfs:
# [[ 1 11]
#  [ 1 18]]
# 	val_precision: 0.6120689655172413
# 	val_recall: 0.9726027397260274
# 	val_auc: 0.5617730679762212
# 	val_cfs:
# [[ 8 45]
#  [ 2 71]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 0.05263157894736842
# 	train_auc: 0.5263157894736842
# 	train_cfs:
# [[12  0]
#  [18  1]]
# 	val_precision: 1.0
# 	val_recall: 0.2054794520547945
# 	val_auc: 0.6027397260273972
# 	val_cfs:
# [[53  0]
#  [58 15]]
#
#
# ========GLIOMA IDH========
# Glioma IDH    38
# Control       12
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 0.0
# 	train_recall: 0.0
# 	train_auc: 0.03947368421052633
# 	train_cfs:
# [[ 3 35]
#  [38  0]]
# 	val_precision: 0.0
# 	val_recall: 0.0
# 	val_auc: 0.06048387096774194
# 	val_cfs:
# [[ 15 109]
#  [ 80   0]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.0
# 	train_recall: 0.0
# 	train_auc: 0.5
# 	train_cfs:
# [[38  0]
#  [38  0]]
# 	val_precision: 1.0
# 	val_recall: 0.0625
# 	val_auc: 0.53125
# 	val_cfs:
# [[124   0]
#  [ 75   5]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.0
# 	train_recall: 0.0
# 	train_auc: 0.5
# 	train_cfs:
# [[38  0]
#  [12  0]]
# 	val_precision: 0.0
# 	val_recall: 0.0
# 	val_auc: 0.5
# 	val_cfs:
# [[124   0]
#  [ 80   0]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 0.08333333333333333
# 	train_auc: 0.5416666666666666
# 	train_cfs:
# [[38  0]
#  [11  1]]
# 	val_precision: 1.0
# 	val_recall: 0.0125
# 	val_auc: 0.50625
# 	val_cfs:
# [[124   0]
#  [ 79   1]]
#
#
# ========HAEMATOPOIETIC========
# Control           17
# Haematopoietic     4
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 0.0
# 	train_recall: 0.0
# 	train_auc: 0.5
# 	train_cfs:
# [[17  0]
#  [17  0]]
# 	val_precision: 0.0
# 	val_recall: 0.0
# 	val_auc: 0.5
# 	val_cfs:
# [[12  0]
#  [75  0]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.5
# 	train_recall: 1.0
# 	train_auc: 0.5
# 	train_cfs:
# [[ 0 17]
#  [ 0 17]]
# 	val_precision: 0.8518518518518519
# 	val_recall: 0.92
# 	val_auc: 0.46
# 	val_cfs:
# [[ 0 12]
#  [ 6 69]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.85
# 	train_recall: 1.0
# 	train_auc: 0.625
# 	train_cfs:
# [[ 1  3]
#  [ 0 17]]
# 	val_precision: 0.872093023255814
# 	val_recall: 1.0
# 	val_auc: 0.5416666666666667
# 	val_cfs:
# [[ 1 11]
#  [ 0 75]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 0.23529411764705882
# 	train_auc: 0.6176470588235294
# 	train_cfs:
# [[ 4  0]
#  [13  4]]
# 	val_precision: 0.7894736842105263
# 	val_recall: 0.2
# 	val_auc: 0.43333333333333335
# 	val_cfs:
# [[ 8  4]
#  [60 15]]
