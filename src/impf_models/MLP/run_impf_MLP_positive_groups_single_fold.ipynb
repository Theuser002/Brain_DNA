# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('../../../src/')
import warnings
warnings.filterwarnings("ignore")

import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import config
import itertools
import utils
import pickle

from utils import impf_make_ndarray_from_csv, get_int_label, brier_score_tensor
from Dataset import CNS
from torch.utils.data import DataLoader
from torch.nn import CrossEntropyLoss
from torch.optim import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score 
from torch.nn.functional import softmax, one_hot
from sklearn.metrics import confusion_matrix
from imblearn.over_sampling import SMOTE, RandomOverSampler
from sklearn.utils.class_weight import compute_class_weight

# %%
class Impf_DNAMLP(nn.Module):
    def __init__ (self, in_features, n_classes):
        super(Impf_DNAMLP, self).__init__()
        self.in_features = in_features
        
        self.n_classes = n_classes
        self.densenet = nn.Sequential(
            nn.Linear(self.in_features, self.n_classes),
        )
        
    def forward (self, x):
        x = self.densenet(x)
        return x

# %%
def impf_train_epoch(epoch, model, train_loader, criterion, optimizer, device):
    correct = 0
    total = 0
    total_loss = 0
    total_bs = 0
    model.to(device)
    model.train()
    
    # For loop through all batches
    all_labels = []
    all_logits = []
    for features, labels in train_loader:
        # Move tensors to device
        features = features.to(device)
        labels = labels.to(device)
        
        # Zero out gradient
        optimizer.zero_grad()
        
        # Forward pass
        logits = model(features)
        loss = criterion(logits, labels)

        # Backward pass
        loss.backward()
        optimizer.step()
        
        # Evaluation
        total_loss += loss.item()
        _, predicted = logits.max(1)
        correct += predicted.eq(labels).sum().item()
        total += labels.size(0)
        
        # batch BS
        batch_bs = brier_score_tensor(logits, labels)
        total_bs += batch_bs
        
        # save logits and labels to calculate AUC
        for logit, label in zip(logits, labels):
            all_labels.append(label.item())
            all_logits.append(np.array(logit.detach().cpu().numpy()))
        
    # epoch's avrage LL
    train_loss = total_loss / len(train_loader)
    # epoch's average acc & ME
    train_acc = (correct / total) * 100.
    train_me = 100 - train_acc
    # epoch's average BS
    train_bs = total_bs/len(train_loader)
    # epoch's average AUC
    # all_labels_one_hot = one_hot(torch.Tensor(np.array(all_labels)).long())
    all_probs = softmax(torch.Tensor(np.array(all_logits)), dim = 1)
    # train_auc = roc_auc_score(all_labels_one_hot, all_probs)
    
    all_preds = [np.argmax(prob) for prob in all_probs]
    train_auc = roc_auc_score(all_labels, all_preds)
    train_precision = precision_score(all_labels, all_preds)
    train_recall = recall_score(all_labels, all_preds)
    train_cfs = confusion_matrix(all_labels, all_preds)
    
    return train_loss, train_acc, train_me, train_bs, train_auc, train_precision, train_recall, train_cfs

def impf_val_epoch(epoch, model, val_loader, criterion, device):
    correct = 0
    total = 0
    total_loss = 0
    total_bs = 0
    model.to(device)
    # For loop through all batches
    with torch.no_grad():
        # For loop through all batches
        all_labels = []
        all_logits = []
        for features, labels in val_loader:
            # Move tensors to device
            features, labels = features.to(device), labels.to(device)
            # Forward pass
            logits = model(features)
            
            # Evaluation and batch loss
            loss = criterion(logits, labels)
            total_loss += loss.item()
            _, predicted = logits.max(1)
            correct += predicted.eq(labels).sum().item()
            total  += labels.size(0)
            
            # batch BS
            batch_bs = brier_score_tensor(logits, labels)
            total_bs += batch_bs
            
            # save logits and labels to calculate AUC
            for logit, label in zip(logits,labels):
                all_labels.append(label.item())
                all_logits.append(np.array(logit.detach().cpu().numpy()))
        
        # epoch's average LL
        val_loss = total_loss / len(val_loader)
        # epoch's average acc & ME
        val_acc = (correct / total) * 100
        val_me = (100 - val_acc)
        # epoch's average BS
        val_bs = total_bs/len(val_loader)
        # epoch's AUC
        # all_labels_one_hot = one_hot(torch.Tensor(np.array(all_labels)).long())
        all_probs = softmax(torch.Tensor(np.array(all_logits)), dim = 1)
        # val_auc = roc_auc_score(all_labels_one_hot, all_probs)
        
        all_preds = [np.argmax(prob) for prob in all_probs]
        val_auc = roc_auc_score(all_labels, all_preds)
        val_precision = precision_score(all_labels, all_preds)
        val_recall = recall_score(all_labels, all_preds)
        val_cfs = confusion_matrix(all_labels, all_preds)
         
    return val_loss, val_acc, val_me, val_bs, val_auc, val_precision, val_recall, val_cfs

def impf_run(class_name, alg, fold, train_loader, val_loader, model, criterion, optimizer, config, save):
    history = {'val_accs': [], 'val_losses': [], 'val_precisions': [], 'val_recalls': [], 'val_aucs': [], 'test_accs': [], 'test_losses': [], 'test_precisions': [], 'test_recalls': [], 'test_aucs': []}
    
    model.to(config['device'])
    n_epochs = config['mlp_n_epochs']
    BEST_STATES_DIR= config['MLP_BEST_STATES_DIR']
    BEST_STATE_PATH = os.path.join(BEST_STATES_DIR, alg, class_name, f'{fold}.pth')
    diff_threshold = config['mlp_diff_threshold']
    max_patience = config['mlp_max_patience']
    patience = 0
    
    for epoch in range(1, n_epochs + 1):
        # print(f'Epoch {epoch}/{n_epochs} of fold {fold} of group {class_name}')
        
        train_loss, train_acc, train_me, train_bs, train_auc, train_precision, train_recall, train_cfs = impf_train_epoch(epoch, model, train_loader, criterion, optimizer, config['device'])
        val_loss, val_acc, val_me, val_bs, val_auc, val_precision, val_recall, val_cfs = impf_val_epoch(epoch, model, val_loader, criterion, config['device'])
        
        # history['val_accs'].append(val_acc)
        history['val_losses'].append(val_loss)
        # history['val_precisions'].append(val_precision)
        # history['val_recalls'].append(val_recall)
        # history['val_aucs'].append(val_auc)
        
        # print(f'[{class_name.upper()}] - {fold} - {epoch}/{n_epochs}')
        # print('train_loss: %.5f | train_acc: %.3f | train_precision: %.3f | train_recall: %.3f | train_auc: %.3f' % (train_loss, train_acc, train_precision, train_bs, train_auc))
        # print('val_loss: %.5f | val_acc: %.3f | val_precision: %.3f | val_recall: %.3f | val_auc: %.3f' % (val_loss, val_acc, val_precision, val_recall, val_auc))
        
        if val_loss == min(history['val_losses']):
            # get best epoch's resutls
            best_epoch_results = {'train_loss: ': train_loss, 'train_accs': train_acc, 'train_me': train_me, 'train_bs': train_bs, 'train_precision': train_precision, 'train_recall': train_recall, 'train_auc': train_auc, 'train_cfs': train_cfs, 'val_loss: ': val_loss, 'val_accs': val_acc, 'val_me': val_me, 'val_bs': val_bs, 'val_precision': val_precision, 'val_recall': val_recall, 'val_auc': val_auc, 'val_cfs': val_cfs}
            if save.lower() == 'save':
                print('Lowest validation loss => saving model weights...')
                torch.save(model.state_dict(), BEST_STATE_PATH)
        if len(history['val_losses']) > 1:
            patience = patience + 1
            # print(f'Patience increased to {patience}')
            if patience == max_patience:
                # print('Early stopping.')
                break
            else:
                patience = 0
        # print('---------------------------------------------')
    return best_epoch_results

# %%
clf_cfg = config.classifier_config
impf_cfg = config.impf_config
groups = utils.positive_groups
folds = utils.outer_folds
fold = folds[np.random.randint(len(folds))]
algs = utils.algs
outer_fold = f'{fold.split(".")[0]}.0'

alg = "MLP"
save = 'no_save'
use_SMOTE_values = [True, False]
use_weights_values = [True, False]
selected_metrics = ['train_precision', 'train_recall', 'train_auc', 'train_cfs', 'val_precision', 'val_recall', 'val_auc', 'val_cfs']

# %%
print(f'root: {config.root_dir}')
print(f"device: {clf_cfg['device']}")
print(f'save mode: {save}')
print(f'fold: {fold}')
print(f'alg: {alg}')
for group in groups:
    print (f'\n\n========{group.upper()}========')
    # Load impf
    with open(os.path.join(impf_cfg['IMPORTANT_FEATURES_DIR'], alg, group, f'{outer_fold}_combined.pkl'), 'rb') as file:
        impf = pickle.load(file)    
    # Read from csv to dataframe
    features, labels = impf_make_ndarray_from_csv(group, fold, impf, mode = 'all')
    # Train test split
    train_features, val_features, train_labels, val_labels = train_test_split(features, labels, test_size=0.8, random_state=42)
    value_counts = pd.Series(train_labels).value_counts()
    print(f'{value_counts}')
    for use_SMOTE in use_SMOTE_values:
        for use_weights in use_weights_values:
            if use_weights == True:
                class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(train_labels), y = train_labels )
            if use_SMOTE == True:
                smote = SMOTE(sampling_strategy = "auto", random_state = 42, k_neighbors = min(value_counts) - 1)
                new_train_features, new_train_labels = smote.fit_resample(train_features, train_labels)
                
            # Encode the labels
            new_train_labels_int = np.array([get_int_label(label, group) for label in new_train_labels])
            val_labels_int = np.array([get_int_label(label, group) for label in val_labels])

            # Create datasets and Dataloaders
            train_dataset = CNS(new_train_features, new_train_labels_int, mode = 'train')
            val_dataset = CNS(val_features, val_labels_int, mode = 'val')
            train_loader = DataLoader(train_dataset, batch_size = impf_cfg['mlp_train_batch_size'], shuffle = True)
            val_loader = DataLoader(val_dataset, batch_size = impf_cfg['mlp_val_batch_size'], shuffle = False)

            # Init model object
            in_features = len(impf)
            model = Impf_DNAMLP(in_features, impf_cfg['n_classes'])
                
            # Define hyperparams
            criterion = CrossEntropyLoss(weight=None)
            optimizer = Adam(model.parameters(), lr = impf_cfg['mlp_lr'], weight_decay = impf_cfg['mlp_weight_decay'])

            best_epoch_results = impf_run(group, alg, fold, train_loader, val_loader, model, criterion, optimizer, impf_cfg, save) 
            print(f'--------\n-> SMOTE: {use_SMOTE} - WEIGHTS: {use_weights} | Best epoch: ')
            for key, value in best_epoch_results.items():
                if key in selected_metrics:
                    if 'cfs' in key:
                        print(f'\t{key}:\n{value}')
                    else:
                        print(f'\t{key}: {value}')
# Out:
# root: /media/data/hungnt/work/SourceCode/Brain_DNA/src/..
# device: cuda
# save mode: no_save
# fold: 3.0
# alg: MLP
#
#
# ========EMBRYONAL========
# Embryonal    124
# Control       21
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 0.9841269841269841
# 	train_recall: 1.0
# 	train_auc: 0.9919354838709677
# 	train_cfs:
# [[122   2]
#  [  0 124]]
# 	val_precision: 0.9245283018867925
# 	val_recall: 1.0
# 	val_auc: 0.9917184265010353
# 	val_cfs:
# [[475   8]
#  [  0  98]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.9841269841269841
# 	train_recall: 1.0
# 	train_auc: 0.9919354838709677
# 	train_cfs:
# [[122   2]
#  [  0 124]]
# 	val_precision: 0.9423076923076923
# 	val_recall: 1.0
# 	val_auc: 0.9937888198757764
# 	val_cfs:
# [[477   6]
#  [  0  98]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 1.0
# 	train_auc: 1.0
# 	train_cfs:
# [[124   0]
#  [  0 124]]
# 	val_precision: 1.0
# 	val_recall: 1.0
# 	val_auc: 1.0
# 	val_cfs:
# [[483   0]
#  [  0  98]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 1.0
# 	train_auc: 1.0
# 	train_cfs:
# [[124   0]
#  [  0 124]]
# 	val_precision: 0.9702970297029703
# 	val_recall: 1.0
# 	val_auc: 0.9968944099378881
# 	val_cfs:
# [[480   3]
#  [  0  98]]
#
#
# ========GLIOBLASTOMA========
# Glioblastoma    85
# Control         23
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 0.8809523809523809
# 	train_recall: 0.43529411764705883
# 	train_auc: 0.6882352941176471
# 	train_cfs:
# [[80  5]
#  [48 37]]
# 	val_precision: 0.49056603773584906
# 	val_recall: 0.2708333333333333
# 	val_auc: 0.5957107843137255
# 	val_cfs:
# [[313  27]
#  [ 70  26]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.9841269841269841
# 	train_recall: 0.7294117647058823
# 	train_auc: 0.8588235294117648
# 	train_cfs:
# [[84  1]
#  [23 62]]
# 	val_precision: 0.8888888888888888
# 	val_recall: 0.3333333333333333
# 	val_auc: 0.6607843137254902
# 	val_cfs:
# [[336   4]
#  [ 64  32]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.9545454545454546
# 	train_recall: 0.9882352941176471
# 	train_auc: 0.9705882352941176
# 	train_cfs:
# [[81  4]
#  [ 1 84]]
# 	val_precision: 0.9313725490196079
# 	val_recall: 0.9895833333333334
# 	val_auc: 0.9844975490196078
# 	val_cfs:
# [[333   7]
#  [  1  95]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 0.9411764705882353
# 	train_recall: 0.9411764705882353
# 	train_auc: 0.9411764705882353
# 	train_cfs:
# [[80  5]
#  [ 5 80]]
# 	val_precision: 0.819047619047619
# 	val_recall: 0.8958333333333334
# 	val_auc: 0.9199754901960785
# 	val_cfs:
# [[321  19]
#  [ 10  86]]
#
#
# ========GLIO-NEURONAL========
# Glio-neuronal    42
# Control          21
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 0.9047619047619048
# 	train_auc: 0.9523809523809523
# 	train_cfs:
# [[42  0]
#  [ 4 38]]
# 	val_precision: 0.9292929292929293
# 	val_recall: 0.9387755102040817
# 	val_auc: 0.9469518576661435
# 	val_cfs:
# [[149   7]
#  [  6  92]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.9117647058823529
# 	train_recall: 0.7380952380952381
# 	train_auc: 0.8333333333333334
# 	train_cfs:
# [[39  3]
#  [11 31]]
# 	val_precision: 0.7894736842105263
# 	val_recall: 0.7653061224489796
# 	val_auc: 0.8185504971219257
# 	val_cfs:
# [[136  20]
#  [ 23  75]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 0.8095238095238095
# 	train_auc: 0.9047619047619048
# 	train_cfs:
# [[42  0]
#  [ 8 34]]
# 	val_precision: 0.925
# 	val_recall: 0.7551020408163265
# 	val_auc: 0.8583202511773941
# 	val_cfs:
# [[150   6]
#  [ 24  74]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 0.8863636363636364
# 	train_recall: 0.9285714285714286
# 	train_auc: 0.9047619047619048
# 	train_cfs:
# [[37  5]
#  [ 3 39]]
# 	val_precision: 0.8207547169811321
# 	val_recall: 0.8877551020408163
# 	val_auc: 0.8829801151229723
# 	val_cfs:
# [[137  19]
#  [ 11  87]]
#
#
# ========SELLA========
# Sella      33
# Control    24
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 0.6226415094339622
# 	train_recall: 1.0
# 	train_auc: 0.696969696969697
# 	train_cfs:
# [[13 20]
#  [ 0 33]]
# 	val_precision: 0.5523255813953488
# 	val_recall: 1.0
# 	val_auc: 0.7169117647058824
# 	val_cfs:
# [[59 77]
#  [ 0 95]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.825
# 	train_recall: 1.0
# 	train_auc: 0.8939393939393939
# 	train_cfs:
# [[26  7]
#  [ 0 33]]
# 	val_precision: 0.8796296296296297
# 	val_recall: 1.0
# 	val_auc: 0.9522058823529411
# 	val_cfs:
# [[123  13]
#  [  0  95]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.673469387755102
# 	train_recall: 1.0
# 	train_auc: 0.7575757575757576
# 	train_cfs:
# [[17 16]
#  [ 0 33]]
# 	val_precision: 0.6078431372549019
# 	val_recall: 0.9789473684210527
# 	val_auc: 0.7688854489164088
# 	val_cfs:
# [[76 60]
#  [ 2 93]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 0.8648648648648649
# 	train_recall: 0.9696969696969697
# 	train_auc: 0.9090909090909092
# 	train_cfs:
# [[28  5]
#  [ 1 32]]
# 	val_precision: 0.689922480620155
# 	val_recall: 0.9368421052631579
# 	val_auc: 0.8213622291021672
# 	val_cfs:
# [[96 40]
#  [ 6 89]]
#
#
# ========EPENDYMAL========
# Ependymal    59
# Control      33
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 0.9152542372881356
# 	train_auc: 0.9576271186440678
# 	train_cfs:
# [[59  0]
#  [ 5 54]]
# 	val_precision: 1.0
# 	val_recall: 0.813953488372093
# 	val_auc: 0.9069767441860466
# 	val_cfs:
# [[284   0]
#  [ 16  70]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.921875
# 	train_recall: 1.0
# 	train_auc: 0.9576271186440678
# 	train_cfs:
# [[54  5]
#  [ 0 59]]
# 	val_precision: 0.7889908256880734
# 	val_recall: 1.0
# 	val_auc: 0.9595070422535211
# 	val_cfs:
# [[261  23]
#  [  0  86]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.8113207547169812
# 	train_recall: 0.7288135593220338
# 	train_auc: 0.7796610169491525
# 	train_cfs:
# [[49 10]
#  [16 43]]
# 	val_precision: 0.6039603960396039
# 	val_recall: 0.7093023255813954
# 	val_auc: 0.78422862757943
# 	val_cfs:
# [[244  40]
#  [ 25  61]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 0.7972972972972973
# 	train_recall: 1.0
# 	train_auc: 0.8728813559322034
# 	train_cfs:
# [[44 15]
#  [ 0 59]]
# 	val_precision: 0.6099290780141844
# 	val_recall: 1.0
# 	val_auc: 0.9031690140845071
# 	val_cfs:
# [[229  55]
#  [  0  86]]
#
#
# ========OTHER GLIOMA========
# Other glioma    67
# Control         22
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 1.0
# 	train_auc: 1.0
# 	train_cfs:
# [[67  0]
#  [ 0 67]]
# 	val_precision: 0.9101123595505618
# 	val_recall: 0.8350515463917526
# 	val_auc: 0.9021411578112609
# 	val_cfs:
# [[252   8]
#  [ 16  81]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 1.0
# 	train_auc: 1.0
# 	train_cfs:
# [[67  0]
#  [ 0 67]]
# 	val_precision: 0.9032258064516129
# 	val_recall: 0.865979381443299
# 	val_auc: 0.9156819984139571
# 	val_cfs:
# [[251   9]
#  [ 13  84]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 0.9850746268656716
# 	train_auc: 0.9925373134328358
# 	train_cfs:
# [[67  0]
#  [ 1 66]]
# 	val_precision: 0.8602150537634409
# 	val_recall: 0.8247422680412371
# 	val_auc: 0.8873711340206185
# 	val_cfs:
# [[247  13]
#  [ 17  80]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 0.9705882352941176
# 	train_recall: 0.9850746268656716
# 	train_auc: 0.9776119402985074
# 	train_cfs:
# [[65  2]
#  [ 1 66]]
# 	val_precision: 0.9222222222222223
# 	val_recall: 0.8556701030927835
# 	val_auc: 0.9143735130848533
# 	val_cfs:
# [[253   7]
#  [ 14  83]]
#
#
# ========NERVE========
# Control    24
# Nerve       6
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 0.5
# 	train_recall: 1.0
# 	train_auc: 0.5
# 	train_cfs:
# [[ 0 24]
#  [ 0 24]]
# 	val_precision: 0.7916666666666666
# 	val_recall: 1.0
# 	val_auc: 0.5
# 	val_cfs:
# [[ 0 25]
#  [ 0 95]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.0
# 	train_recall: 0.0
# 	train_auc: 0.5
# 	train_cfs:
# [[24  0]
#  [24  0]]
# 	val_precision: 0.0
# 	val_recall: 0.0
# 	val_auc: 0.5
# 	val_cfs:
# [[25  0]
#  [95  0]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.8275862068965517
# 	train_recall: 1.0
# 	train_auc: 0.8958333333333333
# 	train_cfs:
# [[19  5]
#  [ 0 24]]
# 	val_precision: 0.95
# 	val_recall: 1.0
# 	val_auc: 0.9
# 	val_cfs:
# [[20  5]
#  [ 0 95]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 0.0
# 	train_recall: 0.0
# 	train_auc: 0.5
# 	train_cfs:
# [[24  0]
#  [24  0]]
# 	val_precision: 0.0
# 	val_recall: 0.0
# 	val_auc: 0.5
# 	val_cfs:
# [[25  0]
#  [95  0]]
#
#
# ========PINEAL========
# Control    28
# Pineal     11
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 0.0
# 	train_recall: 0.0
# 	train_auc: 0.5
# 	train_cfs:
# [[28  0]
#  [28  0]]
# 	val_precision: 0.0
# 	val_recall: 0.0
# 	val_auc: 0.5
# 	val_cfs:
# [[69  0]
#  [91  0]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.5
# 	train_recall: 0.9642857142857143
# 	train_auc: 0.5
# 	train_cfs:
# [[ 1 27]
#  [ 1 27]]
# 	val_precision: 0.5723684210526315
# 	val_recall: 0.9560439560439561
# 	val_auc: 0.5070074852683549
# 	val_cfs:
# [[ 4 65]
#  [ 4 87]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.5555555555555556
# 	train_recall: 0.8928571428571429
# 	train_auc: 0.5892857142857143
# 	train_cfs:
# [[ 8 20]
#  [ 3 25]]
# 	val_precision: 0.626984126984127
# 	val_recall: 0.8681318681318682
# 	val_auc: 0.5934862239210066
# 	val_cfs:
# [[22 47]
#  [12 79]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 0.5
# 	train_recall: 1.0
# 	train_auc: 0.5
# 	train_cfs:
# [[ 0 28]
#  [ 0 28]]
# 	val_precision: 0.56875
# 	val_recall: 1.0
# 	val_auc: 0.5
# 	val_cfs:
# [[ 0 69]
#  [ 0 91]]
#
#
# ========MESENCHYMAL========
# Mesenchymal    34
# Control        23
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 0.7083333333333334
# 	train_recall: 1.0
# 	train_auc: 0.7941176470588236
# 	train_cfs:
# [[20 14]
#  [ 0 34]]
# 	val_precision: 0.631578947368421
# 	val_recall: 1.0
# 	val_auc: 0.7894736842105263
# 	val_cfs:
# [[77 56]
#  [ 0 96]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 0.23529411764705882
# 	train_auc: 0.6176470588235294
# 	train_cfs:
# [[34  0]
#  [26  8]]
# 	val_precision: 0.9411764705882353
# 	val_recall: 0.16666666666666666
# 	val_auc: 0.5795739348370927
# 	val_cfs:
# [[132   1]
#  [ 80  16]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.5714285714285714
# 	train_recall: 0.9411764705882353
# 	train_auc: 0.6176470588235294
# 	train_cfs:
# [[10 24]
#  [ 2 32]]
# 	val_precision: 0.42718446601941745
# 	val_recall: 0.9166666666666666
# 	val_auc: 0.5147243107769424
# 	val_cfs:
# [[ 15 118]
#  [  8  88]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 1.0
# 	train_auc: 1.0
# 	train_cfs:
# [[34  0]
#  [ 0 34]]
# 	val_precision: 0.9789473684210527
# 	val_recall: 0.96875
# 	val_auc: 0.9768562030075189
# 	val_cfs:
# [[131   2]
#  [  3  93]]
#
#
# ========MELANOCYTIC========
# Control        24
# Melanocytic     5
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 0.4782608695652174
# 	train_recall: 0.9166666666666666
# 	train_auc: 0.4583333333333333
# 	train_cfs:
# [[ 0 24]
#  [ 2 22]]
# 	val_precision: 0.8035714285714286
# 	val_recall: 0.9473684210526315
# 	val_auc: 0.47368421052631576
# 	val_cfs:
# [[ 0 22]
#  [ 5 90]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.5
# 	train_recall: 1.0
# 	train_auc: 0.5
# 	train_cfs:
# [[ 0 24]
#  [ 0 24]]
# 	val_precision: 0.811965811965812
# 	val_recall: 1.0
# 	val_auc: 0.5
# 	val_cfs:
# [[ 0 22]
#  [ 0 95]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.5
# 	train_recall: 0.6666666666666666
# 	train_auc: 0.5
# 	train_cfs:
# [[ 8 16]
#  [ 8 16]]
# 	val_precision: 0.8181818181818182
# 	val_recall: 0.6631578947368421
# 	val_auc: 0.5133971291866029
# 	val_cfs:
# [[ 8 14]
#  [32 63]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 0.6486486486486487
# 	train_recall: 1.0
# 	train_auc: 0.7291666666666667
# 	train_cfs:
# [[11 13]
#  [ 0 24]]
# 	val_precision: 0.8636363636363636
# 	val_recall: 1.0
# 	val_auc: 0.6590909090909092
# 	val_cfs:
# [[ 7 15]
#  [ 0 95]]
#
#
# ========PLEXUS========
# Control    24
# Plexus     16
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 0.4864864864864865
# 	train_recall: 0.75
# 	train_auc: 0.4791666666666667
# 	train_cfs:
# [[ 5 19]
#  [ 6 18]]
# 	val_precision: 0.6142857142857143
# 	val_recall: 0.9052631578947369
# 	val_auc: 0.5496465043205028
# 	val_cfs:
# [[13 54]
#  [ 9 86]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.4411764705882353
# 	train_recall: 0.625
# 	train_auc: 0.4166666666666667
# 	train_cfs:
# [[ 5 19]
#  [ 9 15]]
# 	val_precision: 0.45454545454545453
# 	val_recall: 0.5789473684210527
# 	val_auc: 0.29693637077769053
# 	val_cfs:
# [[ 1 66]
#  [40 55]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.5106382978723404
# 	train_recall: 1.0
# 	train_auc: 0.5208333333333333
# 	train_cfs:
# [[ 1 23]
#  [ 0 24]]
# 	val_precision: 0.59375
# 	val_recall: 1.0
# 	val_auc: 0.5149253731343284
# 	val_cfs:
# [[ 2 65]
#  [ 0 95]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 0.5
# 	train_recall: 1.0
# 	train_auc: 0.5
# 	train_cfs:
# [[ 0 24]
#  [ 0 24]]
# 	val_precision: 0.5864197530864198
# 	val_recall: 1.0
# 	val_auc: 0.5
# 	val_cfs:
# [[ 0 67]
#  [ 0 95]]
#
#
# ========GLIOMA IDH========
# Glioma IDH    40
# Control       24
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 0.58
# 	train_recall: 0.725
# 	train_auc: 0.6
# 	train_cfs:
# [[19 21]
#  [11 29]]
# 	val_precision: 0.422360248447205
# 	val_recall: 0.7157894736842105
# 	val_auc: 0.5743581514762517
# 	val_cfs:
# [[71 93]
#  [27 68]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.2
# 	train_recall: 0.025
# 	train_auc: 0.46249999999999997
# 	train_cfs:
# [[36  4]
#  [39  1]]
# 	val_precision: 0.32142857142857145
# 	val_recall: 0.09473684210526316
# 	val_auc: 0.48944159178433894
# 	val_cfs:
# [[145  19]
#  [ 86   9]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 1.0
# 	train_recall: 0.45
# 	train_auc: 0.725
# 	train_cfs:
# [[40  0]
#  [22 18]]
# 	val_precision: 1.0
# 	val_recall: 0.5473684210526316
# 	val_auc: 0.7736842105263158
# 	val_cfs:
# [[164   0]
#  [ 43  52]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 0.38636363636363635
# 	train_recall: 0.425
# 	train_auc: 0.375
# 	train_cfs:
# [[13 27]
#  [23 17]]
# 	val_precision: 0.24516129032258063
# 	val_recall: 0.4
# 	val_auc: 0.34329268292682924
# 	val_cfs:
# [[ 47 117]
#  [ 57  38]]
#
#
# ========HAEMATOPOIETIC========
# Control           24
# Haematopoietic     4
# dtype: int64
# --------
# -> SMOTE: True - WEIGHTS: True | Best epoch:
# 	train_precision: 0.5
# 	train_recall: 1.0
# 	train_auc: 0.5
# 	train_cfs:
# [[ 0 24]
#  [ 0 24]]
# 	val_precision: 0.8454545454545455
# 	val_recall: 0.9789473684210527
# 	val_auc: 0.48947368421052634
# 	val_cfs:
# [[ 0 17]
#  [ 2 93]]
# --------
# -> SMOTE: True - WEIGHTS: False | Best epoch:
# 	train_precision: 0.3333333333333333
# 	train_recall: 0.125
# 	train_auc: 0.4375
# 	train_cfs:
# [[18  6]
#  [21  3]]
# 	val_precision: 0.5294117647058824
# 	val_recall: 0.09473684210526316
# 	val_auc: 0.3120743034055728
# 	val_cfs:
# [[ 9  8]
#  [86  9]]
# --------
# -> SMOTE: False - WEIGHTS: True | Best epoch:
# 	train_precision: 0.0
# 	train_recall: 0.0
# 	train_auc: 0.5
# 	train_cfs:
# [[24  0]
#  [24  0]]
# 	val_precision: 0.0
# 	val_recall: 0.0
# 	val_auc: 0.5
# 	val_cfs:
# [[17  0]
#  [95  0]]
# --------
# -> SMOTE: False - WEIGHTS: False | Best epoch:
# 	train_precision: 0.5
# 	train_recall: 1.0
# 	train_auc: 0.5
# 	train_cfs:
# [[ 0 24]
#  [ 0 24]]
# 	val_precision: 0.8482142857142857
# 	val_recall: 1.0
# 	val_auc: 0.5
# 	val_cfs:
# [[ 0 17]
#  [ 0 95]]
